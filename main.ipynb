# %% [markdown]
# # Task A - 1 hour
# ##### Import Python libraries.

# %%
import pandas as pd

# %% [markdown]
# ##### Import the CSV file → NSMES1988.csv into a dataframe.

# %%
hospital_df = pd.read_csv('NSMES1988 - NSMES1988.csv')

# %% [markdown]
# ##### Check for missing values in the data.

# %%
hospital_df.isna().any()
# Out:
# Unnamed: 0    False
# visits        False
# nvisits       False
# ovisits       False
# novisits      False
# emergency     False
# hospital      False
# health        False
# chronic       False
# adl           False
# region        False
# age           False
# gender        False
# married       False
# school        False
# income        False
# employed      False
# insurance     False
# medicaid      False
# dtype: bool

# %%
hospital_df.isnull().any()
# Out:
# Unnamed: 0    False
# visits        False
# nvisits       False
# ovisits       False
# novisits      False
# emergency     False
# hospital      False
# health        False
# chronic       False
# adl           False
# region        False
# age           False
# gender        False
# married       False
# school        False
# income        False
# employed      False
# insurance     False
# medicaid      False
# dtype: bool

# %% [markdown]
#     `   No missing values found

# %% [markdown]
# ##### Perform memory analysis of the dataframe and mark your comments.

# %%
hospital_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4406 entries, 0 to 4405
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  4406 non-null   int64
#  1   visits      4406 non-null   int64
#  2   nvisits     4406 non-null   int64
#  3   ovisits     4406 non-null   int64
#  4   novisits    4406 non-null   int64
#  5   emergency   4406 non-null   int64
#  6   hospital    4406 non-null   int64
#  7   health      4406 non-null   object
#  8   chronic     4406 non-null   int64
#  9   adl         4406 non-null   object
#  10  region      4406 non-null   object
#  11  age         4406 non-null   float64
#  12  gender      4406 non-null   object
#  13  married     4406 non-null   object
#  14  school      4406 non-null   int64
#  15  income      4406 non-null   float64
#  16  employed    4406 non-null   object
#  17  insurance   4406 non-null   object
#  18  medicaid    4406 non-null   object
# ...

# %% [markdown]
#         There are multiple columns that can be converted from object datatype to boolean. Age can be as an int instead of a float. There are other datatypes that can be converted if we wanted to be as efficient as possible, but for readability and access sense, we believe it makes sense to stick with the original

# %% [markdown]
# ##### Perform the following operations on the columns.

# %% [markdown]
# ##### Rename any nondescript columns to be more specific.

# %%
hospital_df = hospital_df.rename(columns={'adl':'daily_activities'})
hospital_df
# Out:
#       Unnamed: 0  visits  nvisits  ovisits  novisits  emergency  hospital  \
# 0              1       5        0        0         0          0         1
# 1              2       1        0        2         0          2         0
# 2              3      13        0        0         0          3         3
# 3              4      16        0        5         0          1         1
# 4              5       3        0        0         0          0         0
# ...          ...     ...      ...      ...       ...        ...       ...
# 4401        4402      11        0        0         0          0         0
# 4402        4403      12        0        0         0          0         0
# 4403        4404      10        0       20         0          1         1
# 4404        4405      16        1        0         0          0         0
# 4405        4406       0        0        0         0          0         0
#
#          health  chronic daily_activities region  age  gender married  school  \
# ...

# %% [markdown]
# ##### Multiply age by 10 and income by 10000.

# %%
hospital_df['age'] = hospital_df['age'] * 10
hospital_df['income'] = hospital_df['income'] * 10000

hospital_df
# Out:
#       Unnamed: 0  visits  nvisits  ovisits  novisits  emergency  hospital  \
# 0              1       5        0        0         0          0         1
# 1              2       1        0        2         0          2         0
# 2              3      13        0        0         0          3         3
# 3              4      16        0        5         0          1         1
# 4              5       3        0        0         0          0         0
# ...          ...     ...      ...      ...       ...        ...       ...
# 4401        4402      11        0        0         0          0         0
# 4402        4403      12        0        0         0          0         0
# 4403        4404      10        0       20         0          1         1
# 4404        4405      16        1        0         0          0         0
# 4405        4406       0        0        0         0          0         0
#
#          health  chronic daily_activities region   age  gender married  \
# ...

# %% [markdown]
# Would any column benefit from changing data types?
#
#         Yes
# Indicate possible data type changes, in the report.
#
#         Done

# %% [markdown]
# ##### Save the dataframe as ‘NSMES1988_updated.csv’ file in the local space for future use.

# %%
hospital_df.to_csv('NSMES1988_updated.csv')

# %% [markdown]
# ##### Perform basic statistical analysis on your dataframe

# %%
# Correlation Matrix
print(hospital_df.corr(numeric_only=True))

#Number of unique values and datatype or each column
for col in hospital_df.columns:
    print(f"Column: {col}")
    print(f"  Unique values: {hospital_df[col].nunique()}")
    print(f"  Data Types: {hospital_df[col].dtypes}")
# Out:
#             Unnamed: 0    visits   nvisits   ovisits  novisits  emergency  \
# Unnamed: 0    1.000000 -0.021873  0.009741 -0.000072  0.015489  -0.002922
# visits       -0.021873  1.000000  0.226365  0.068144  0.078468   0.158748
# nvisits       0.009741  0.226365  1.000000  0.001129  0.041768   0.049056
# ovisits      -0.000072  0.068144  0.001129  1.000000  0.466923   0.065388
# novisits      0.015489  0.078468  0.041768  0.466923  1.000000   0.024083
# emergency    -0.002922  0.158748  0.049056  0.065388  0.024083   1.000000
# hospital      0.012327  0.240789  0.050401  0.110573  0.065301   0.476061
# chronic       0.002928  0.261886  0.037113  0.100805  0.040748   0.203845
# age          -0.014648  0.003404 -0.041640 -0.040028 -0.032813   0.061023
# school       -0.033246  0.064433  0.085974 -0.012156 -0.011733  -0.071192
# income        0.001205 -0.004951  0.010731 -0.004267 -0.007786  -0.026462
#
#             hospital   chronic       age    school    income
# ...

# %% [markdown]
# Generate a brief report on the outcome
#
#         Report content in the bottom

# %% [markdown]
# ##### Invoke describe command on the dataframe and compare that with the basic statistical analysis done in the previous step.

# %%
hospital_df.describe()
# Out:
#         Unnamed: 0       visits      nvisits      ovisits     novisits  \
# count  4406.000000  4406.000000  4406.000000  4406.000000  4406.000000
# mean   2203.500000     5.774399     1.618021     0.750794     0.536087
# std    1272.046972     6.759225     5.317056     3.652759     3.879506
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%    1102.250000     1.000000     0.000000     0.000000     0.000000
# 50%    2203.500000     4.000000     0.000000     0.000000     0.000000
# 75%    3304.750000     8.000000     1.000000     0.000000     0.000000
# max    4406.000000    89.000000   104.000000   141.000000   155.000000
#
#          emergency     hospital      chronic          age       school  \
# count  4406.000000  4406.000000  4406.000000  4406.000000  4406.000000
# mean      0.263504     0.295960     1.541988    74.024058    10.290286
# std       0.703659     0.746398     1.349632     6.334050     3.738736
# ...

# %% [markdown]
#         Basic Statistical Analysis:
#             Individual statistical values is required.
#             Got to do Multiple function calls
#             Less convenient as it requires more steps
#             Requires different approaches for numeric & categorical data
#
#         Describe():
#             DataFrame/Series with multiple statistics
#             Just a single function call provides complete analysis
#             Quicker resolution
#             Simpler approach

# %% [markdown]
# ##### Indicate which of the columns are not eligible for statistical analysis.
#
#         Columns that are not of a number datatype are not eligible for statistical analysis

# %% [markdown]
# ##### Prepare a brief report and enter it in the markdown cells of a JupyterLab Notebook.

# %% [markdown]
#         Report content provided throughout Notebook file

# %% [markdown]
# # Task B - 1 hour
# Import Data-Viz libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Generate a plot depicting the relative number of people who were insured vs not insured
# - Make sure to document your findings

# %%
def custom_label(pct, allvals):
    absolute = int(pct / 100 * sum(allvals))
    return f"{pct:.1f}%\n({absolute})"

# Pie
data = hospital_df['insurance'].value_counts()
print(data)
labels = ['Insured', 'Uninsured']

plt.pie(data, labels=labels, autopct=lambda pct: custom_label(pct, data))
plt.title('Insured vs Uninsured visitors')
plt.show()
# Out:
# insurance
# yes    3421
# no      985
# Name: count, dtype: int64

# %% [markdown]
#         TO DO

# %% [markdown]
# Generate plots depicting the correlation (if any) between a given type of hospital visit and the health of individuals.
# - I.e. Do people with health category, x, visit the hospital in a given manner more, the same, or less often than people in
# health category, y, typed people?
# - Make sure to document your findings

# %%
hospital_df['hospital_visits'] = hospital_df['ovisits'] + hospital_df['novisits'] + hospital_df['emergency']
grouped_df = hospital_df.groupby('health').agg(avg_visits=pd.NamedAgg(column='hospital', aggfunc='mean'))

sns.barplot(data=grouped_df, x='health', y='avg_visits', color='green')

plt.title('Hospital visits per health category')

plt.show()

# %% [markdown]
#         Visitors with the health category of Poor visit the hospital the most. This is followed by those with average health and lastly those with excellent health

# %% [markdown]
# Is there any relationship between income and private insurance? Between income and Medicaid?
# - Make sure to document your findings

# %%
# Private insurance is yes/no
# Income is unique per row, float

hospital_df['income_quartile'] = pd.qcut(hospital_df['income'], q=4, labels=['Q1', 'Q2', 'Q3', 'Q4'])

sns.catplot(data = hospital_df, x='insurance', y='income', kind='box')
sns.catplot(data = hospital_df, x='medicaid', y='income', kind='box')

# %% [markdown]
#           For this exercise, we assumed that the insurace value of 'yes' is private insurance and "no" is uninsured
#
#         There is a relationship between income and insurance. We see that those with insurance tend to have a higher income than those without

# %% [markdown]
# Create 2 or more plots of your choosing that help you tell a story with the data.
# - (Experimentation may be required to find something worth reporting on, or just go with your instincts)
# - This is completely up to your Team
# - Make sure to document your findings
# - Make sure there are insights to be learned with your plots

# %%
# Health vs Region
sns.countplot(data=hospital_df, x="region", hue="health")

plt.title("Health by Region")
plt.ylabel("People")
plt.xticks(rotation=45)
plt.show()

hospital_df['age_quartile'] = pd.qcut(hospital_df['age'], q=4, labels=['Q1', 'Q2', 'Q3', 'Q4'])

sns.countplot(data=hospital_df, x="age_quartile", hue="health")

plt.title("Health by Age")
plt.ylabel("People")
plt.xticks(rotation=45)
plt.show()

# Age vs 

#

# %% [markdown]
#           Insights into health by age and region
#
#           We used bar graphs to show insights into health by age and region
#
#           Health by Age Quartiles
#           - the oldest quartile
#                - has the highest count of individuals in poor health
#                - has the lowest count of individuals in excellent health
#           - the youngest quartile
#                - is the largest group
#                - has most individuals in average and excellent health
#           - in general
#                - the percentages of people in each category seem similar among the age groups
#                - we may want to look further into the percentages to verify this
#           Health by region
#           - the other region
#                - is the largest group
#                - has most individuals in each health group - average, poor and excellent health
#                - has a much higher ratio of individuals in poor health compared to excellent health
#           - in midwest, northeast, and west regions
#                - the ratio of people in poor health to excellent health is closer to one,
#                - while in the west region excellent health exceeds poor health
#                - computing ratios of the groups and percentages would provide more insights

# %% [markdown]
# # Task C - 30 Minutes

# %% [markdown]
# Generate a final report of your team’s EDA for the Hospital

# %% [markdown]
# Ensure that you detail →
# - All actions your Team performed on the data
# - Any insights you had while working with the data
# - Is there any recommendations to the hospital for future data collection, (What could they do
# better)

# %% [markdown]
# Create a story with the data, and use your graphs to tell that story -
# - Make sure that your description is through
# - What information is being learned from this analysis?
# - What questions are still unknown?

# %% [markdown]
# ##### Report:

# %% [markdown]
# # Analysis of Factors Influencing Hospital Visits
#
# ## Executive Summary
# This report examines the relationship between insurance status, income, health conditions, and hospital visits using data from the given hospital csv. We found that uninsured individuals have a significantly lower average income than insured individuals and that certain health categories are associated with a higher frequency of hospital visits. High-income outliers were observed among the insured population, warranting further investigation.
#
# ---
#
# ## 1. Introduction
#
# - **Background**: Understanding the factors affecting hospital utilization is critical for healthcare planning and policy.
# - **Purpose**: To identify key drivers of hospital visits.
# - **Research Questions**:
#   - What is the relationship between insurance status and income?
#   - How does income relate to hospital visits?
#   - Are there differences in hospital visit frequency across different health categories?
#
# ---
#
# ## 2. Data and Methods
#
# - **Data Source**: hospital_df
#
# - **Data Cleaning and Transformation**:
#   - Handling missing values (if any)
#   - Data type conversions (e.g., string to boolean, string to category)
#   - Creation of new variables (e.g., `Age * Income`)
#
# - **Analytical Methods**:
#   - Descriptive statistics (mean, median, standard deviation)
#   - Data visualization (histograms, scatter plots, box plots, bar charts)
#   - Statistical tests (if applicable, e.g., t-tests, chi-squared tests)
#
# ---
#
# ## 3. Results
#
# ### Insurance Coverage
# - **Plot**: Bar chart showing the percentage of insured vs. uninsured individuals
# - **Description**: “22.4% of the population in this dataset is uninsured.”
#
# ### Income and Insurance Status
# - **Plot**: Box plot comparing the distribution of income for insured vs. uninsured individuals
# - **Description**: “The average income of insured individuals is significantly higher than that of uninsured individuals. However, there are high-income outliers among the insured.”
#
# ### Income and Medicaid
# - **Plot**: Box plot comparing the distribution of income for those with and without Medicaid
# - **Description**: “Surprisingly, the average income of individuals with Medicaid is higher than those without. This warrants further investigation.”
#
# ### Hospital Visits by Health Category:
# - **Plot**: Bar chart showing the number of hospital visits for each health category.
# - **Description**: "Individuals with [Specific Health Condition] have the highest number of hospital visits."
#
# ### Age and Hospital Visits:
# - **Plot**: Scatter plot or line plot showing the relationship between age and hospital visits.
# - **Description**: "Hospital visits tend to increase with age."
#
# ---
#
# ## Limitations of the analysis:
# - Potential biases in the data.
# - Assumptions made during data cleaning and transformation.
# - Confounding factors that were not considered.
#
# ## Potential next steps:
# - Further investigation of the high-income outliers among the insured.
# - Examination of the relationship between income, insurance status, and specific health conditions.
# - Collection of additional data to address the limitations of the analysis.
#
# ## Conclusion
#
# ### Summary of the key findings:
# - Insurance status and income are strongly related.
# - Certain health conditions are associated with higher hospital visit frequencies.
# - Age is also a factor in increasing hospital visits.
#
# ### Implications of the findings:
# - These findings can inform policies aimed at improving access to healthcare and reducing hospital utilization.
# - Further research is needed to understand the complex interplay of factors influencing hospital visits.
# - Once I have the details about your plots and analysis, I can create a more tailored and helpful report outline for you.
